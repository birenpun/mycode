# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/student/mycode/challange/annualcheeseconsumed.txt')
df.head()
# Out:
#    Year  Cheddar  American Other  Mozzarella  Italian other  Swiss  Brick  \
# 0  1970     5.79            1.20        1.19           0.87   0.88   0.10
# 1  1971     5.91            1.42        1.38           0.92   0.94   0.11
# 2  1972     6.01            1.67        1.57           1.02   1.06   0.10
# 3  1973     6.07            1.76        1.76           1.03   1.06   0.11
# 4  1974     6.31            2.16        1.86           1.09   1.18   0.11
#
#    Muenster  Cream and Neufchatel  Blue  Other Dairy Cheese  Processed Cheese  \
# 0      0.17                  0.61  0.15                0.41              3.32
# 1      0.19                  0.62  0.15                0.41              3.55
# 2      0.22                  0.63  0.17                0.56              3.51
# 3      0.21                  0.66  0.18                0.65              3.31
# 4      0.23                  0.70  0.16                0.61              3.42
#
# ...

# %%
df = df.set_index('Year')
df.head()
# Out:
#       Cheddar  American Other  Mozzarella  Italian other  Swiss  Brick  \
# Year
# 1970     5.79            1.20        1.19           0.87   0.88   0.10
# 1971     5.91            1.42        1.38           0.92   0.94   0.11
# 1972     6.01            1.67        1.57           1.02   1.06   0.10
# 1973     6.07            1.76        1.76           1.03   1.06   0.11
# 1974     6.31            2.16        1.86           1.09   1.18   0.11
#
#       Muenster  Cream and Neufchatel  Blue  Other Dairy Cheese  \
# Year
# 1970      0.17                  0.61  0.15                0.41
# 1971      0.19                  0.62  0.15                0.41
# 1972      0.22                  0.63  0.17                0.56
# 1973      0.21                  0.66  0.18                0.65
# 1974      0.23                  0.70  0.16                0.61
#
#       Processed Cheese  Foods and spreads  Total American Chese  \
# Year
# 1970              3.32               2.20                  7.00
# ...

# %%
to_drop = ['American Other',
           'Mozzarella',
           'Italian other',
           'Brick',
           'Cream and Neufchatel',
           'Blue',
           'Other Dairy Cheese',
           'Processed Cheese',
           'Foods and spreads',
          'Total American Chese',
          'Total Italian Cheese',
          'Total Natural Cheese',
          'Total Processed Cheese Products']

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#       Cheddar  Swiss  Muenster
# Year
# 1970     5.79   0.88      0.17
# 1971     5.91   0.94      0.19
# 1972     6.01   1.06      0.22
# 1973     6.07   1.06      0.21
# 1974     6.31   1.18      0.23

# %%
# sort DataFrame based on Gross Earnings
recentdf= short_df.sort_values(["Year"], ascending=False)
recentdf.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 2
#       1 # sort DataFrame based on Gross Earnings
# ----> 2 recentdf= short_df.sort_values(["Year"], ascending=False)
#       3 recentdf.head(2)
#
# NameError: name 'short_df' is not defined
